# %% [markdown]
# <a href="https://colab.research.google.com/github/tnphammy/Microsoft-2B-document-intelligence-agent-harness/blob/main/notebooks/extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setting up

# %% [markdown]
# ## Installing libraries

# %%
import pandas as pd
# !pip install pymupdf
# !pip install python-docx

# %%
url = 'https://github.com/tnphammy/Microsoft-2B-document-intelligence-agent-harness/tree/fc1cd37f3be73720e422ae9d5ff1923ab2a410cc/data'
