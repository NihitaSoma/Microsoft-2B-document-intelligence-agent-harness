# %% [markdown]
# <a href="https://colab.research.google.com/github/NihitaSoma/Microsoft-2B-document-intelligence-agent-harness/blob/chunking/phase_1_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# ## Install libraries

# %%
import os
import pathlib
import pandas as pd
# !pip install pymupdf
# !pip install pymupdf4llm
# !pip install python-docx
# !pip install 'markitdown[all]'
# !pip install -U langchain-text-splitters
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.28.2-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (26 kB)
# Downloading pymupdf-1.28.2-cp310-abi3-manylinux_2_28_x86_64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 58.2 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.28.2
# Collecting pymupdf4llm
#   Downloading pymupdf4llm-1.28.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pymupdf==1.28.2 in /usr/local/lib/python3.13/dist-packages (from pymupdf4llm) (1.28.2)
# Collecting pymupdf_layout==1.28.2 (from pymupdf4llm)
#   Downloading pymupdf_layout-1.28.2-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.13/dist-packages (from pymupdf4llm) (0.9.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from pymupdf4llm) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from pymupdf_layout==1.28.2->pymupdf4llm) (6.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from pymupdf_layout==1.28.2->pymupdf4llm) (2.1.3)
# Collecting onnxruntime (from pymupdf_layout==1.28.2->pymupdf4llm)
#   Downloading onnxruntime-1.30.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.13/dist-packages (from pymupdf_layout==1.28.2->pymupdf4llm) (3.6.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.13/dist-packages (from onnxruntime->pymupdf_layout==1.28.2->pymupdf4llm) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from onnxruntime->pymupdf_layout==1.28.2->pymupdf4llm) (26.3)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.13/dist-packages (from onnxruntime->pymupdf_layout==1.28.2->pymupdf4llm) (5.29.6)
# Downloading pymupdf4llm-1.28.2-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 6.9 MB/s eta 0:00:00
# Downloading pymupdf_layout-1.28.2-cp310-abi3-manylinux_2_28_x86_64.whl (42.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 MB 17.3 MB/s eta 0:00:00
# Downloading onnxruntime-1.30.0-cp313-cp313-manylinux_2_28_x86_64.whl (23.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 44.8 MB/s eta 0:00:00
# Installing collected packages: onnxruntime, pymupdf_layout, pymupdf4llm
# Successfully installed onnxruntime-1.30.0 pymupdf4llm-1.28.2 pymupdf_layout-1.28.2
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from python-docx) (6.1.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.13/dist-packages (from python-docx) (4.16.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0
# Collecting markitdown[all]
#   Downloading markitdown-0.1.8-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (4.13.5)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (3.4.9)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (0.7.1)
# Collecting magika~=0.6.1 (from markitdown[all])
#   Downloading magika-0.6.3-py3-none-manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting markdownify (from markitdown[all])
#   Downloading markdownify-1.2.3-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (2.32.4)
# Collecting azure-ai-contentunderstanding>=1.2.0b1 (from markitdown[all])
#   Downloading azure_ai_contentunderstanding-1.2.0b3-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.4 MB/s eta 0:00:00
# Collecting azure-ai-documentintelligence (from markitdown[all])
#   Downloading azure_ai_documentintelligence-1.0.2-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.0 MB/s eta 0:00:00
# Collecting azure-identity (from markitdown[all])
#   Downloading azure_identity-1.25.3-py3-none-any.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (6.1.2)
# Collecting mammoth~=1.11.0 (from markitdown[all])
#   Downloading mammoth-1.11.0-py2.py3-none-any.whl.metadata (26 kB)
# Collecting olefile (from markitdown[all])
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (3.1.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (2.2.3)
# Collecting pdfminer-six>=20251230 (from markitdown[all])
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Collecting pdfplumber>=0.11.9 (from markitdown[all])
#   Downloading pdfplumber-0.11.10-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pydub in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (0.25.1)
# Collecting python-pptx (from markitdown[all])
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting speechrecognition (from markitdown[all])
#   Downloading speechrecognition-3.17.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.13/dist-packages (from markitdown[all]) (2.0.2)
# Collecting youtube-transcript-api~=1.2.3 (from markitdown[all])
#   Downloading youtube_transcript_api-1.2.4-py3-none-any.whl.metadata (24 kB)
# Collecting isodate>=0.6.1 (from azure-ai-contentunderstanding>=1.2.0b1->markitdown[all])
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.37.0 (from azure-ai-contentunderstanding>=1.2.0b1->markitdown[all])
#   Downloading azure_core-1.41.0-py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.13/dist-packages (from azure-ai-contentunderstanding>=1.2.0b1->markitdown[all]) (4.16.0)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.13/dist-packages (from magika~=0.6.1->markitdown[all]) (8.5.0)
# Requirement already satisfied: onnxruntime>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from magika~=0.6.1->markitdown[all]) (1.30.0)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from magika~=0.6.1->markitdown[all]) (2.1.3)
# Requirement already satisfied: python-dotenv>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from magika~=0.6.1->markitdown[all]) (1.2.3)
# Collecting cobble<0.2,>=0.1.3 (from mammoth~=1.11.0->markitdown[all])
#   Downloading cobble-0.1.4-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.13/dist-packages (from pdfminer-six>=20251230->markitdown[all]) (50.0.1)
# Collecting Pillow>=12.2.0 (from pdfplumber>=0.11.9->markitdown[all])
#   Downloading pillow-12.3.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pypdfium2>=5.9.0 (from pdfplumber>=0.11.9->markitdown[all])
#   Downloading pypdfium2-5.13.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 3.8 MB/s eta 0:00:00
# Collecting msal>=1.35.1 (from azure-identity->markitdown[all])
#   Downloading msal-1.39.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity->markitdown[all])
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->markitdown[all]) (2.9.2)
# Requirement already satisfied: six<2,>=1.15 in /usr/local/lib/python3.13/dist-packages (from markdownify->markitdown[all]) (1.17.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.13/dist-packages (from openpyxl->markitdown[all]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->markitdown[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->markitdown[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->markitdown[all]) (2026.3)
# Collecting XlsxWriter>=0.5.7 (from python-pptx->markitdown[all])
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->markitdown[all]) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->markitdown[all]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->markitdown[all]) (2026.7.22)
# Requirement already satisfied: standard-aifc in /usr/local/lib/python3.13/dist-packages (from speechrecognition->markitdown[all]) (3.13.0)
# Requirement already satisfied: audioop-lts in /usr/local/lib/python3.13/dist-packages (from speechrecognition->markitdown[all]) (0.2.2)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20251230->markitdown[all]) (2.1.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity->markitdown[all]) (2.13.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (26.3)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (5.29.6)
# Requirement already satisfied: standard-chunk in /usr/local/lib/python3.13/dist-packages (from standard-aifc->speechrecognition->markitdown[all]) (3.13.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six>=20251230->markitdown[all]) (3.0)
# Downloading azure_ai_contentunderstanding-1.2.0b3-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.2/127.2 kB 4.7 MB/s eta 0:00:00
# Downloading magika-0.6.3-py3-none-manylinux_2_28_x86_64.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 38.6 MB/s eta 0:00:00
# Downloading mammoth-1.11.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 2.6 MB/s eta 0:00:00
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 71.0 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.10-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.1 MB/s eta 0:00:00
# Downloading youtube_transcript_api-1.2.4-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.2/485.2 kB 15.8 MB/s eta 0:00:00
# Downloading azure_ai_documentintelligence-1.0.2-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 5.1 MB/s eta 0:00:00
# Downloading azure_identity-1.25.3-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 kB 10.6 MB/s eta 0:00:00
# Downloading markdownify-1.2.3-py3-none-any.whl (15 kB)
# Downloading markitdown-0.1.8-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 5.1 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 6.6 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 18.1 MB/s eta 0:00:00
# Downloading speechrecognition-3.17.0-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 18.8 MB/s eta 0:00:00
# Downloading azure_core-1.41.0-py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 13.6 MB/s eta 0:00:00
# Downloading cobble-0.1.4-py3-none-any.whl (4.0 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.39.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 8.1 MB/s eta 0:00:00
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading pillow-12.3.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 82.5 MB/s eta 0:00:00
# Downloading pypdfium2-5.13.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 61.5 MB/s eta 0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: XlsxWriter, pypdfium2, Pillow, olefile, isodate, cobble, youtube-transcript-api, speechrecognition, python-pptx, markdownify, mammoth, magika, azure-core, pdfminer-six, markitdown, azure-ai-documentintelligence, azure-ai-contentunderstanding, pdfplumber, msal, msal-extensions, azure-identity
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
# Successfully installed Pillow-12.3.0 XlsxWriter-3.2.9 azure-ai-contentunderstanding-1.2.0b3 azure-ai-documentintelligence-1.0.2 azure-core-1.41.0 azure-identity-1.25.3 cobble-0.1.4 isodate-0.7.2 magika-0.6.3 mammoth-1.11.0 markdownify-1.2.3 markitdown-0.1.8 msal-1.39.0 msal-extensions-1.3.1 olefile-0.47 pdfminer-six-20260107 pdfplumber-0.11.10 pypdfium2-5.13.0 python-pptx-1.0.2 speechrecognition-3.17.0 youtube-transcript-api-1.2.4
# Collecting langchain-text-splitters
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /usr/local/lib/python3.13/dist-packages (from langchain-text-splitters) (1.6.1)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.4)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.10.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: langchain-text-splitters
# Successfully installed langchain-text-splitters-1.1.2

# %% [markdown]
# ## Import Data

# %% [markdown]
# ### Import Files

# %%
data_path = '/content/data'

# %%
dir_list = os.listdir(data_path)
print("Files and directories in '", data_path, "' :")
# prints all files
print(dir_list)
# Out:
# Files and directories in ' /content/data ' :
# ['northstar_laboratory_safety_handbook_2026.docx', 'northstar_student_handbook_and_campus_services_2026.pdf', 'northstar_academic_integrity_policy_2026.pdf', 'northstar_internship_guidelines_2026.docx', 'northstar_library_services_and_use_rules_2026.pdf', 'northstar_examination_and_grading_policy_2026.pdf', 'northstar_scholarship_and_financial_aid_guide_2026.pdf', 'northstar_examination_and_grading_policy_2025.pdf', 'northstar_admissions_and_enrollment_guide_2026.pdf', 'northstar_attendance_and_course_participation_policy_2026.docx']

# %% [markdown]
# ### Sort Files

# %%
# Separate list of PDF's and DOCX's
all_pdf = []
all_docx = []

# Sort by PDF and DOCX
for file in dir_list:
  if file.endswith('.pdf'):
    all_pdf.append(file)
  elif file.endswith('.docx'):
    all_docx.append(file)

print(len(all_pdf), " PDFs: ", all_pdf)
print(len(all_docx), " DOCXs: ", all_docx)
# Out:
# 7  PDFs:  ['northstar_student_handbook_and_campus_services_2026.pdf', 'northstar_academic_integrity_policy_2026.pdf', 'northstar_library_services_and_use_rules_2026.pdf', 'northstar_examination_and_grading_policy_2026.pdf', 'northstar_scholarship_and_financial_aid_guide_2026.pdf', 'northstar_examination_and_grading_policy_2025.pdf', 'northstar_admissions_and_enrollment_guide_2026.pdf']
# 3  DOCXs:  ['northstar_laboratory_safety_handbook_2026.docx', 'northstar_internship_guidelines_2026.docx', 'northstar_attendance_and_course_participation_policy_2026.docx']

# %% [markdown]
# # Phase 1: Extraction

# %%
# Pandas DF to store all extractable information
cols = ["filename", "filepath", "file_type", "md_text", "metadata"]
df = pd.DataFrame(columns=cols)

# %% [markdown]
# ## PDF's - PyMuPDF

# %%
import pymupdf, pymupdf4llm

def extract_pdf_to_entry(pdf:str) -> list:
  """
  Extracts markdown content from pdf file.

  Args:
    pdf: local pdf file

  Returns
    data_entry: a row of information formatted as a list to add to pandas dataframe
  """

  # Get full file path
  file_path = os.path.join(data_path, pdf)

  # Generate markdown
  md_text = pymupdf4llm.to_markdown(file_path)

  # Get metadata
  metadata = pymupdf.open(file_path).metadata

  # Make data entry for this instance in order of: filename, filepath, file_type, md_text, metadata
  data_entry = [pdf, file_path, "pdf", md_text, metadata]

  return data_entry

# Add data_entry as a row in the df
for pdf in all_pdf:
  df.loc[len(df)] = extract_pdf_to_entry(pdf)

display(df.head(7))
# Out:
# === Document parser messages ===
# Using Tesseract for OCR processing.
#
# === Document parser messages ===
# Using Tesseract for OCR processing.
#
# === Document parser messages ===
# Using Tesseract for OCR processing.
#
# === Document parser messages ===
# Using Tesseract for OCR processing.
#
# === Document parser messages ===
# Using Tesseract for OCR processing.
#
# === Document parser messages ===
# Using Tesseract for OCR processing.
#
# === Document parser messages ===
# Using Tesseract for OCR processing.
#                                             filename  \
# 0  northstar_student_handbook_and_campus_services...
# 1       northstar_academic_integrity_policy_2026.pdf
# 2  northstar_library_services_and_use_rules_2026.pdf
# 3  northstar_examination_and_grading_policy_2026.pdf
# 4  northstar_scholarship_and_financial_aid_guide_...
# 5  northstar_examination_and_grading_policy_2025.pdf
# 6  northstar_admissions_and_enrollment_guide_2026...
#
#                                             filepath file_type  \
# 0  /content/data/northstar_student_handbook_and_c...       pdf
# 1  /content/data/northstar_academic_integrity_pol...       pdf
# 2  /content/data/northstar_library_services_and_u...       pdf
# 3  /content/data/northstar_examination_and_gradin...       pdf
# 4  /content/data/northstar_scholarship_and_financ...       pdf
# 5  /content/data/northstar_examination_and_gradin...       pdf
# 6  /content/data/northstar_admissions_and_enrollm...       pdf
#
#                                              md_text  \
# 0  **NORTHSTAR UNIVERSITY** |  NSU-STUDENT-2026 \...
# 1  **NORTHSTAR UNIVERSITY** |  NSU-INTEGRITY-2026...
# 2  **NORTHSTAR UNIVERSITY** |  NSU-LIB-2026 \n\n#...
# 3  **NORTHSTAR UNIVERSITY** |  NSU-EXAM-2026 \n\n...
# 4  **NORTHSTAR UNIVERSITY** |  NSU-AID-2026 \n\n#...
# 5  **NORTHSTAR UNIVERSITY** |  NSU-EXAM-2025 \n\n...
# 6  **NORTHSTAR UNIVERSITY** |  NSU-ADMIT-2026 \n\...
#
#                                             metadata
# 0  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 1  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 2  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 3  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 4  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 5  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 6  {'format': 'PDF 1.7', 'title': '', 'author': '...

# %% [markdown]
# ## DOCX's - python-docx + MarkItDown

# %%
from datetime import datetime
from docx import Document
from markitdown import MarkItDown


# Helper function to reformat python datetime objects to our standard format
def format_date(dt):
    if isinstance(dt, datetime):
        # Formats to a PDF-like date string: D:YYYYMMDDHHMMSS
        return f"D:{dt.strftime('%Y%m%d%H%M%S')}"
    return ""

# Iterate through all DOCX's - fill in DataFrame
def extract_docx_to_entry(docx:str) -> list:
  """
  Extracts markdown content from docx file.

  Args:
    docx: local docx file

  Returns
    data_entry: a row of information formatted as a list to add to pandas dataframe
  """
  # 0. Get full filepath
  file_path = os.path.join(data_path, docx)

  # 1. Get markdown text - MarkItDown
  md = MarkItDown()
  result = md.convert(file_path)
  md_text = result.text_content

  # 2.1. Get metadata - python-docx
  doc = Document(file_path) # Pass file_path here, not docx
  props = doc.core_properties

  # 2.2. Reformat metadata
  metadata = {
      "format": "DOCX",  # Explicit file format
      "title": props.title or "",
      "author": props.author or "",
      "subject": props.subject or "",
      "keywords": props.keywords or "",
      "creator": props.last_modified_by or "",  # Fallback to last modifier
      "producer": "python-docx & Microsoft Word",
      "creationDate": format_date(props.created),
      "modDate": format_date(props.modified),
      "trapped": "",
      "encryption": None,  # docx files aren't encrypted natively this way
  }

  # Make data entry for this instance in order of: filename, filepath, file_type, md_text, metadata
  data_entry = [docx, file_path, "docx", md_text, metadata]

  return data_entry

# Add data_entry as a row in the df
for docx in all_docx:
  df.loc[len(df)] = extract_docx_to_entry(docx)


display(df.tail(3))
# Out:
#                                              filename  \
# 10     northstar_laboratory_safety_handbook_2026.docx
# 11          northstar_internship_guidelines_2026.docx
# 12  northstar_attendance_and_course_participation_...
#
#                                              filepath file_type  \
# 10  /content/data/northstar_laboratory_safety_hand...      docx
# 11  /content/data/northstar_internship_guidelines_...      docx
# 12  /content/data/northstar_attendance_and_course_...      docx
#
#                                               md_text  \
# 10  **Undergraduate Laboratory Safety Handbook**\n...
# 11  **Undergraduate Internship Guidelines**\n\n**A...
# 12  **Attendance and Course Participation Policy**...
#
#                                              metadata
# 10  {'format': 'DOCX', 'title': 'Undergraduate Lab...
# 11  {'format': 'DOCX', 'title': 'Undergraduate Int...
# 12  {'format': 'DOCX', 'title': 'Attendance and Co...

# %%
# Examine current Dataframe
display(df.head(10))
# Out:
#                                             filename  \
# 0  northstar_student_handbook_and_campus_services...
# 1       northstar_academic_integrity_policy_2026.pdf
# 2  northstar_library_services_and_use_rules_2026.pdf
# 3  northstar_examination_and_grading_policy_2026.pdf
# 4  northstar_scholarship_and_financial_aid_guide_...
# 5  northstar_examination_and_grading_policy_2025.pdf
# 6  northstar_admissions_and_enrollment_guide_2026...
# 7     northstar_laboratory_safety_handbook_2026.docx
# 8          northstar_internship_guidelines_2026.docx
# 9  northstar_attendance_and_course_participation_...
#
#                                             filepath file_type  \
# 0  /content/data/northstar_student_handbook_and_c...       pdf
# 1  /content/data/northstar_academic_integrity_pol...       pdf
# 2  /content/data/northstar_library_services_and_u...       pdf
# 3  /content/data/northstar_examination_and_gradin...       pdf
# 4  /content/data/northstar_scholarship_and_financ...       pdf
# 5  /content/data/northstar_examination_and_gradin...       pdf
# 6  /content/data/northstar_admissions_and_enrollm...       pdf
# 7  /content/data/northstar_laboratory_safety_hand...      docx
# 8  /content/data/northstar_internship_guidelines_...      docx
# 9  /content/data/northstar_attendance_and_course_...      docx
#
#                                              md_text  \
# 0  **NORTHSTAR UNIVERSITY** |  NSU-STUDENT-2026 \...
# 1  **NORTHSTAR UNIVERSITY** |  NSU-INTEGRITY-2026...
# 2  **NORTHSTAR UNIVERSITY** |  NSU-LIB-2026 \n\n#...
# 3  **NORTHSTAR UNIVERSITY** |  NSU-EXAM-2026 \n\n...
# 4  **NORTHSTAR UNIVERSITY** |  NSU-AID-2026 \n\n#...
# 5  **NORTHSTAR UNIVERSITY** |  NSU-EXAM-2025 \n\n...
# 6  **NORTHSTAR UNIVERSITY** |  NSU-ADMIT-2026 \n\...
# 7  **Undergraduate Laboratory Safety Handbook**\n...
# 8  **Undergraduate Internship Guidelines**\n\n**A...
# 9  **Attendance and Course Participation Policy**...
#
#                                             metadata
# 0  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 1  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 2  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 3  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 4  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 5  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 6  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 7  {'format': 'DOCX', 'title': 'Undergraduate Lab...
# 8  {'format': 'DOCX', 'title': 'Undergraduate Int...
# 9  {'format': 'DOCX', 'title': 'Attendance and Co...

# %% [markdown]
# # Phase 2: Chunk Text

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Create the text splitter
# chunk_size = maximum number of characters in each chunk
# chunk_overlap = number of characters shared between neighboring chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=550,
    chunk_overlap=75,
    separators=["\n\n", "\n", ". ", " ", ""]
)

# Store all chunks here
chunked_data = []

# Go through every file in the DataFrame
for _, row in df.iterrows():

    # Get the extracted markdown text
    text = row["md_text"]

    # Skip files with no extracted text
    if not text or not text.strip():
        continue

    # Split the document into chunks
    chunks = text_splitter.split_text(text)

    # Create one entry for every chunk
    for chunk_id, chunk in enumerate(chunks):

        chunked_data.append({
            "filename": row["filename"],
            "filepath": row["filepath"],
            "file_type": row["file_type"],
            "chunk_id": chunk_id,
            "text": chunk,
            "metadata": row["metadata"]
        })

# Create a new DataFrame containing the chunks
chunks_df = pd.DataFrame(chunked_data)

# Examine the results
display(chunks_df.head(10))
# Out:
#                                             filename  \
# 0  northstar_student_handbook_and_campus_services...
# 1  northstar_student_handbook_and_campus_services...
# 2  northstar_student_handbook_and_campus_services...
# 3  northstar_student_handbook_and_campus_services...
# 4  northstar_student_handbook_and_campus_services...
# 5  northstar_student_handbook_and_campus_services...
# 6  northstar_student_handbook_and_campus_services...
# 7  northstar_student_handbook_and_campus_services...
# 8  northstar_student_handbook_and_campus_services...
# 9       northstar_academic_integrity_policy_2026.pdf
#
#                                             filepath file_type  chunk_id  \
# 0  /content/data/northstar_student_handbook_and_c...       pdf         0
# 1  /content/data/northstar_student_handbook_and_c...       pdf         1
# 2  /content/data/northstar_student_handbook_and_c...       pdf         2
# 3  /content/data/northstar_student_handbook_and_c...       pdf         3
# 4  /content/data/northstar_student_handbook_and_c...       pdf         4
# 5  /content/data/northstar_student_handbook_and_c...       pdf         5
# 6  /content/data/northstar_student_handbook_and_c...       pdf         6
# 7  /content/data/northstar_student_handbook_and_c...       pdf         7
# 8  /content/data/northstar_student_handbook_and_c...       pdf         8
# 9  /content/data/northstar_academic_integrity_pol...       pdf         0
#
#                                                 text  \
# 0  **NORTHSTAR UNIVERSITY** |  NSU-STUDENT-2026 \...
# 1  ## **1. Identification, Campus Access, and Con...
# 2  Threats, harassment, theft, vandalism, dangero...
# 3  ## **2. Health, Counseling, and Emergency Supp...
# 4  Students seeking disability-related academic a...
# 5  ## **3. Withdrawal and Tuition Refunds** \n\nA...
# 6  Admission-deposit refunds and financial-aid re...
# 7  ## **4. Campus Services and Complaints** \n\nT...
# 8  The general information line is 555-2101. The ...
# 9  **NORTHSTAR UNIVERSITY** |  NSU-INTEGRITY-2026...
#
#                                             metadata
# 0  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 1  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 2  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 3  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 4  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 5  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 6  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 7  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 8  {'format': 'PDF 1.7', 'title': '', 'author': '...
# 9  {'format': 'PDF 1.7', 'title': '', 'author': '...

# %% [markdown]
# # Phase 3: Embeddings

# %% [markdown]
# # Phase 4: Depluplication & Verification
